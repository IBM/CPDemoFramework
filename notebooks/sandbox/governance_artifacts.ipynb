# %%
# %load_ext autoreload
# %autoreload 2
import logging
import pandas

logging.basicConfig(format="%(asctime)s %(levelname)-7s %(message)s", level=logging.INFO)
import sys
sys.path.append('../..')
from apis import endpoints, MainAPI, usecases

categoriesAPI = endpoints.CategoriesAPI()
termsAPI = endpoints.TermsAPI()
mainAPI = MainAPI()
refDataAPI = endpoints.RefDataAPI(mainAPI)
# Out:
# 2022-03-16 07:59:20,703 INFO    URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-16 07:59:21,362 INFO    HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....ChaPT0fuLqPkfa168Ni08COUl-W8VnukAWk2-erxzxsts7frF82RME3UXsR4X9vziBd5MtOcVufemKtEJm-CqvGuaBBUVMFDgBdAHpAIi6_wirLFcB-FkciG6xlBOj3v7DHmR3y7qZ7gxwckfIV6MN3WUN-W6wV0NlVDl5gysAgXwz1v4tlvjTYbYxEh4E9KqgAQE_Ro5beSE0Z6knGbc5XL79-OwM6gOV-J6GR2IlssNUnx1gxzeeoJqFV5h4UYR6mGhKUA35iOzEaDvRhnd5sYmztQF5AmEsyhFTkSFGoa7gr3lpl6TALsiaMjehDbqfgwAQzxvypxg13WkN48DQ'}
# 2022-03-16 07:59:21,362 INFO    URL: https://datafabric.ibmcloudpack.com:12864
# ...

# %%
# Get list of categories and export to csv
categoriesJSON = mainAPI.search(f'metadata.artifact_type:category')
categoriesAPI.categories2CSV(categoriesJSON,"categories_export.csv")
categoriesTable = pandas.read_csv('categories_export.csv')        
categoriesTable
# Out:
# 2022-03-15 23:19:11,635 INFO    GET /v3/search?query=metadata.artifact_type:category
#                             artifact_id  \
# 0  4f043e06-e9c6-4b33-a89e-98dbc93a1295
# 1  d93d184d-6cea-458d-8525-64be89ba578d
# 2  adfaa0b1-5162-43eb-a125-23c96fc09974
# 3  dfa16ce2-bf03-4743-b3dd-4a85348be6dd
# 4  d4efb010-d158-4e47-a63d-3750ee9665d2
# 5  caff718c-1247-4c75-a41b-a75d94b0d739
# 6  eebd338d-dbd5-37e4-9e4a-1296de82963a
# 7  b066a536-c294-48f0-8311-47f9c71947f6
# 8  e39ada11-8338-3704-90e3-681a71e7c839
#
#                                          description             name  \
# 0          updated category long description for POT           apicat
# 1                                     updated fsdfss         cat-1234
# 2                                        updated NaN         Property
# 3                          updated Air handling unit              AHU
# 4          updated category long description for POT          apicat2
# ...

# %%
# Update the CSV file and review changes
categoriesTable = pandas.read_csv('categories_export.csv')        
categoriesTable
# Out:
#                             artifact_id  \
# 0  4f043e06-e9c6-4b33-a89e-98dbc93a1295
# 1  d93d184d-6cea-458d-8525-64be89ba578d
# 2  adfaa0b1-5162-43eb-a125-23c96fc09974
# 3  dfa16ce2-bf03-4743-b3dd-4a85348be6dd
# 4  d4efb010-d158-4e47-a63d-3750ee9665d2
# 5  caff718c-1247-4c75-a41b-a75d94b0d739
# 6  eebd338d-dbd5-37e4-9e4a-1296de82963a
# 7  b066a536-c294-48f0-8311-47f9c71947f6
# 8  e39ada11-8338-3704-90e3-681a71e7c839
#
#                                          description             name  \
# 0          updated category long description for POT           apicat
# 1                                     updated fsdfss         cat-1234
# 2                                        updated NaN         Property
# 3                          updated Air handling unit              AHU
# 4          updated category long description for POT          apicat2
# 5                       updated Employee information         Employee
# ...

# %%
# Bring categories back to object for bulk updates to catalog
categoriesTable = pandas.read_csv('categories_export.csv')        
categoriesAPI.updateCategoriesFromTable(categoriesTable)
# Out:
# 2022-03-15 23:04:35,195 INFO    GET /v3/search?query=entity.artifacts.artifact_id:4f043e06-e9c6-4b33-a89e-98dbc93a1295
# 2022-03-15 23:04:35,857 INFO    GET /v3/categories/4f043e06-e9c6-4b33-a89e-98dbc93a1295
# 2022-03-15 23:04:36,089 INFO    PATCH /v3/categories/4f043e06-e9c6-4b33-a89e-98dbc93a1295
# 2022-03-15 23:04:36,090 INFO    PAYLOAD: {'long_description': 'updated category long description for POT', 'name': 'apicat', 'steward_ids': [], 'tags': []}
# 2022-03-15 23:04:36,260 INFO    {
#   "metadata": {
#     "artifact_type": "category",
#     "artifact_id": "4f043e06-e9c6-4b33-a89e-98dbc93a1295",
#     "version_id": "9628fe17-9be8-4aad-914b-f7dff71a50ea_2",
#     "source_repository_id": "4e07dd80-9270-43f4-a804-f7c7b967870f",
#     "global_id": "4e07dd80-9270-43f4-a804-f7c7b967870f_4f043e06-e9c6-4b33-a89e-98dbc93a1295",
#     "published_ancestor_id": "9628fe17-9be8-4aad-914b-f7dff71a50ea_1",
#     "created_by": "1000330999",
#     "created_at": "2022-03-11T01:53:39.286Z",
# ...

# %%
# Create new categories from file
categoriesTable = pandas.read_csv('new_categories.csv')        
for index, row in categoriesTable.iterrows():
    categoriesAPI.createCategory(row['name'], row['short_description'], row['long_description'])
# Out:
# 2022-03-15 23:28:31,582 INFO    POST /v3/categories
# 2022-03-15 23:28:31,583 INFO    PAYLOAD: {'long_description': ' cat1 long', 'name': 'cat1', 'short_description': ' cat1 short'}
# 2022-03-15 23:28:32,308 INFO    POST /v3/categories
# 2022-03-15 23:28:32,309 INFO    PAYLOAD: {'long_description': ' cat12 long', 'name': 'cat12', 'short_description': ' cat12 short'}
# 2022-03-15 23:28:32,923 INFO    POST /v3/categories
# 2022-03-15 23:28:32,924 INFO    PAYLOAD: {'long_description': ' cat13 long', 'name': 'cat13', 'short_description': ' cat13 short'}
# 2022-03-15 23:28:33,341 INFO    POST /v3/categories
# 2022-03-15 23:28:33,342 INFO    PAYLOAD: {'long_description': ' cat14 long', 'name': 'cat14', 'short_description': ' cat14 short'}

# %%
# Get list of terms 
termsJSON = mainAPI.search(f'metadata.artifact_type:glossary_term')
termsAPI.terms2CSV(termsJSON, 'terms_export.csv')
# Out:
# 2022-03-15 23:33:34,941 INFO    GET /v3/search?query=metadata.artifact_type:glossary_term

# %%
# Check existing terms
termTable = pandas.read_csv('terms_export.csv')        
termTable
# Out:
#                             artifact_id                          description  \
# 0  6a46db60-f75b-47cf-bc0b-fffc0cad6861  updated This is a new business term
# 1  f1285b4b-732f-4d6b-b8fe-b45767ad5388                                  NaN
#
#           name steward_ids tags
# 0    Demo term          []   []
# 1  custom attr          []   []

# %%
# Update existing terms and re-read into table and update catalog

termTable = pandas.read_csv('terms_export.csv')        
termTable
termsAPI.updateTermsFromTable(termTable)
# Out:
# 2022-03-15 23:36:09,153 INFO    GET /v3/search?query=entity.artifacts.artifact_id:6a46db60-f75b-47cf-bc0b-fffc0cad6861
# 2022-03-15 23:36:09,799 INFO    GET /v3/glossary_terms/6a46db60-f75b-47cf-bc0b-fffc0cad6861/versions/99e1e221-c619-4387-8b6d-e2e53f440705_1?all_parents=true
# 2022-03-15 23:36:10,004 INFO    PATCH /v3/glossary_terms/6a46db60-f75b-47cf-bc0b-fffc0cad6861/versions/99e1e221-c619-4387-8b6d-e2e53f440705_1?skip_workflow_if_possible=True
# 2022-03-15 23:36:10,005 INFO    PAYLOAD: {'revision': '1', 'long_description': 'updated This is a new business term', 'name': 'Demo term', 'steward_ids': [], 'tags': []}
# 2022-03-15 23:36:10,611 INFO    {
#   "metadata": {
#     "artifact_type": "glossary_term",
#     "artifact_id": "6a46db60-f75b-47cf-bc0b-fffc0cad6861",
#     "version_id": "99e1e221-c619-4387-8b6d-e2e53f440705_2",
#     "source_repository_id": "4e07dd80-9270-43f4-a804-f7c7b967870f",
# ...

# %%
termsTable = pandas.read_csv('new_terms.csv')    
    
for index, row in termsTable.iterrows():
    termAbbreviations = [row['name'][0:2]]
    termsAPI.createTerm(termAbbreviations, row['name'], row['short_description'], row['long_description'])
# Out:
# 2022-03-15 23:45:56,496 INFO    POST /v3/glossary_terms?skip_workflow_if_possible=True
# 2022-03-15 23:45:56,496 INFO    PAYLOAD: [{'abbreviations': ['AB'], 'long_description': 'AB long description', 'name': 'ABTerm', 'short_description': 'AB short descripton'}]
# 2022-03-15 23:45:56,968 INFO    POST /v3/glossary_terms?skip_workflow_if_possible=True
# 2022-03-15 23:45:56,969 INFO    PAYLOAD: [{'abbreviations': ['BC'], 'long_description': 'BC long description', 'name': 'BCTerm', 'short_description': 'BC short description'}]
# 2022-03-15 23:45:57,219 INFO    POST /v3/glossary_terms?skip_workflow_if_possible=True
# 2022-03-15 23:45:57,219 INFO    PAYLOAD: [{'abbreviations': ['CD'], 'long_description': 'CD long description', 'name': 'CDTerm', 'short_description': 'CD short description'}]

# %%
resJSON = mainAPI.search('metadata.artifact_type:reference_data')
for refData in resJSON["rows"]:
    print(refData["artifact_id"]+"--"+refData["metadata"]["name"])
# Out:
# 2022-03-16 08:28:54,354 INFO    GET /v3/search?query=metadata.artifact_type:reference_data
# 534561ac-1080-3714-b7aa-5a5809ff1f00--Sovereign Locations
# c57cb90f-2126-3800-9c9f-9eab82021cdf--Physical Locations

# %%
# write reference dataset to csv
artifact_id="534561ac-1080-3714-b7aa-5a5809ff1f00"
filename = 'refDataTest.csv'
refDataAPI.getRefDataCSV(artifact_id, filename)
pandas.read_csv(filename)
# Out:
# 2022-03-16 08:29:36,964 INFO    GET /v3/search?query=entity.artifacts.artifact_id:534561ac-1080-3714-b7aa-5a5809ff1f00
# 2022-03-16 08:29:37,365 INFO    GET /v3/reference_data/534561ac-1080-3714-b7aa-5a5809ff1f00/versions/7b460a0f-1dfd-4bab-b3e8-8b8aae3b5e2d_0/values
# 2022-03-16 08:29:37,599 INFO    "code","value","description","parent","is_multi_mapped_to_Locations>>Physical Locations"
# "US","United States of America","United States of America",,"DAL"
# "UK","United Kingdom","United Kingdom",,"LON"
# "JP","Japan","Japan",,"TOK"
# "EU","European Union","European Union",,
# "AU","Australia","Australia",,
# "DE","Germany","Germany","EU","FRA"
#   code                     value               description parent  \
# 0   US  United States of America  United States of America    NaN
# 1   UK            United Kingdom            United Kingdom    NaN
# 2   JP                     Japan                     Japan    NaN
# 3   EU            European Union            European Union    NaN
# ...

# %%
# upload updated reference dataset
refDataAPI.loadRefDataFromCSV(artifact_id, filename)

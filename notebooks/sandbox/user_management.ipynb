# %%
# %load_ext autoreload
# %autoreload 2
import logging
logging.basicConfig(format="%(asctime)s %(levelname)-7s %(message)s", level=logging.INFO)
import pandas
import sys
sys.path.append('../..')
import apis
userApi = apis.endpoints.UsersAPI()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/pgirish/Downloads/wkc-api/notebooks/sandbox/user_management.ipynb Cell 1' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/pgirish/Downloads/wkc-api/notebooks/sandbox/user_management.ipynb#ch0000000?line=2'>3</a> import logging
#       <a href='vscode-notebook-cell:/Users/pgirish/Downloads/wkc-api/notebooks/sandbox/user_management.ipynb#ch0000000?line=3'>4</a> logging.basicConfig(format="%(asctime)s %(levelname)-7s %(message)s", level=logging.INFO)
# ----> <a href='vscode-notebook-cell:/Users/pgirish/Downloads/wkc-api/notebooks/sandbox/user_management.ipynb#ch0000000?line=4'>5</a> import pandas
#       <a href='vscode-notebook-cell:/Users/pgirish/Downloads/wkc-api/notebooks/sandbox/user_management.ipynb#ch0000000?line=5'>6</a> import sys
#       <a href='vscode-notebook-cell:/Users/pgirish/Downloads/wkc-api/notebooks/sandbox/user_management.ipynb#ch0000000?line=6'>7</a> sys.path.append('../..')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Get current users
usersJSON = userApi.getAllUsers()
userApi.users2CSV(usersJSON, 'users_export.csv')
usersTable = pandas.read_csv('users_export.csv')        
usersTable
# Out:
# 2022-03-16 07:39:25,565 INFO    GET /icp4d-api/v1/users
#                          displayName                  email  \
# 0                              admin                     --
# 1                     Data Scientist  datascientist@ibm.com
# 2                       Data Steward    datasteward@ibm.com
# 3                      Data Engineer   dataengineer@ibm.com
# 4                       Data Analyst      dqanalyst@ibm.com
# 5   Data Scientist and Engineer Lead         dslead@ibm.com
# 6                            UAT ops         uatops@ibm.com
# 7                           Prod Ops        prodops@ibm.com
# 8                     Reporting user             ba@ibm.com
# 9           BaDisplay164680159049410         BA11@gmail.com
# 10                            Girish          girish@in.com
# 11                              Amol            amol@in.com
# 12                         CP4DUser1       CP4DUser1@in.com
# 13                         CP4DUser2       CP4DUser2@in.com
# 14                         CP4DUser3       CP4DUser3@in.com
# 15                            Rajesh          rajeh1@in.com
# 16                         CP4DDemo5          rajeh1@in.com
# 17                            User 1          user1@ibm.com
#
#                                           permissions         uid  \
# 0   ['administrator', 'can_provision', 'manage_cat...  1000330999
# 1   ['access_catalog', 'create_project', 'create_s...  1000331002
# 2   ['create_project', 'manage_information_assets'...  1000331003
# 3   ['create_project', 'author_governance_artifact...  1000331004
# 4   ['create_project', 'manage_information_assets'...  1000331005
# 5   ['access_catalog', 'create_project', 'create_s...  1000331006
# 6   ['access_catalog', 'create_project', 'create_s...  1000331007
# 7   ['access_catalog', 'create_project', 'create_s...  1000331008
# 8   ['create_project', 'access_catalog', 'access_i...  1000331009
# 9   ['create_project', 'access_catalog', 'access_i...  1000331010
# 10  ['create_project', 'access_catalog', 'access_i...  1000331026
# 11  ['create_project', 'access_catalog', 'access_i...  1000331031
# 12  ['create_project', 'access_catalog', 'access_i...  1000331034
# 13  ['create_project', 'access_catalog', 'access_i...  1000331035
# 14  ['create_project', 'access_catalog', 'access_i...  1000331036
# 15  ['create_project', 'access_catalog', 'access_i...  1000331037
# 16  ['create_project', 'access_catalog', 'access_i...  1000331039
# 17  ['access_catalog', 'create_project', 'create_s...  1000331040
#
#                                            user_roles               username
# 0   ['zen_administrator_role', 'zen_developer_role...                  admin
# 1                         ['wkc_data_scientist_role']          datascientist
# 2                           ['wkc_data_steward_role']            datasteward
# 3                          ['zen_data_engineer_role']           dataengineer
# 4                   ['wkc_data_quality_analyst_role']              dqanalyst
# 5   ['wkc_data_scientist_role', 'zen_data_engineer...                 dslead
# 6                         ['wkc_data_scientist_role']                 uatops
# 7                         ['wkc_data_scientist_role']                prodops
# 8                       ['wkc_business_analyst_role']              potbauser
# 9                       ['wkc_business_analyst_role']  bauser164680159049451
# 10                      ['wkc_business_analyst_role']                 girish
# 11                      ['wkc_business_analyst_role']                   amol
# 12                      ['wkc_business_analyst_role']              cp4duser1
# 13                      ['wkc_business_analyst_role']              cp4duser2
# 14                      ['wkc_business_analyst_role']              cp4duser3
# 15                      ['wkc_business_analyst_role']                 rajesh
# 16                      ['wkc_business_analyst_role']              cp4ddemo5
# 17                        ['wkc_data_scientist_role']                  user1

# %%
# Add new users from CSV
usersTable = pandas.read_csv('new_users.csv')        
userApi.updateUsersFromTable(usersTable)
# Out:
# 2022-03-16 07:39:20,332 INFO    POST /icp4d-api/v1/users
# 2022-03-16 07:39:20,333 INFO    PAYLOAD: {'user_name': 'user1', 'password': 'passw0rd', 'displayName': 'User 1', 'user_roles': ['Data Scientist'], 'email': 'user1@ibm.com'}

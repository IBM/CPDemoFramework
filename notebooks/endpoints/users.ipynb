# %%
# %load_ext autoreload
# %autoreload 2
import logging
logging.basicConfig(format="%(asctime)s %(levelname)-7s %(message)s", level=logging.DEBUG)
import pandas
import sys
sys.path.append('../..')
import apis
api = apis.endpoints.UsersAPI()
# Out:
# 2022-03-14 15:04:50,732 DEBUG   calling SubAPI init
# 2022-03-14 15:04:50,733 DEBUG   None
# 2022-03-14 15:04:50,734 INFO    URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-14 15:04:50,742 DEBUG   Starting new HTTPS connection (1): datafabric.ibmcloudpack.com:12864
# 2022-03-14 15:04:51,204 DEBUG   https://datafabric.ibmcloudpack.com:12864 "POST /icp4d-api/v1/authorize HTTP/1.1" 200 1261
# 2022-03-14 15:04:51,205 INFO    HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....lqLnRZXJX01oScGFegm6Qlt3VxMQLObFMR3FSrE8zSSooYg2rHHCbJ6sB-STJyoVRfZG549DykDMyYN6YiF9QbUTgMusT6TvR2Gf2wI9Ed6HPlGIOyDhyLjVgEv8ioRrfnUMcVje4n_lZgIEeJlvno1smkn5dyGDLE7wSb6H1K8pSEuFvvqodXBJ_gIXLr8s7JkrRDaaawRkHtl9SOkwMywrzjos9gr-h73hT1wlt2NI01xcX0YAryXHTbInta1bS9tn8gCcpmv8-Obg0BTLvECluRMNZHE1-avXg-QDdrQWEVlWfwGNqfSRjHrDQ5GdSlhsV1A8406OZTQz0rdOTQ'}
# ...

# %%
usersJSON = api.getAllUsers()
usersJSON
#len(res["UsersInfo"])
# Out:
# 2022-03-14 15:04:54,837 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-14 15:04:54,838 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....lqLnRZXJX01oScGFegm6Qlt3VxMQLObFMR3FSrE8zSSooYg2rHHCbJ6sB-STJyoVRfZG549DykDMyYN6YiF9QbUTgMusT6TvR2Gf2wI9Ed6HPlGIOyDhyLjVgEv8ioRrfnUMcVje4n_lZgIEeJlvno1smkn5dyGDLE7wSb6H1K8pSEuFvvqodXBJ_gIXLr8s7JkrRDaaawRkHtl9SOkwMywrzjos9gr-h73hT1wlt2NI01xcX0YAryXHTbInta1bS9tn8gCcpmv8-Obg0BTLvECluRMNZHE1-avXg-QDdrQWEVlWfwGNqfSRjHrDQ5GdSlhsV1A8406OZTQz0rdOTQ', 'Content-Type': 'application/json'}
# 2022-03-14 15:04:55,043 INFO    GET /icp4d-api/v1/users
# 2022-03-14 15:04:55,315 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /icp4d-api/v1/users HTTP/1.1" 200 None
# 2022-03-14 15:04:55,316 DEBUG   Res: <Response [200]>
# ...

# %%
# Schritt 2 : Schreibe User daten in CSV
api.users2CSV(usersJSON, '../csv/userlist_out.csv')
api.users2Table(usersJSON)
# Out:
# 2022-03-14 15:05:03,621 DEBUG   [{'approval_status': 'approved', 'authenticator': 'default', 'created_timestamp': '2022-01-05 14:41:34.602 +0000 UTC', 'current_account_status': 'enabled', 'displayName': 'admin', 'email': '--', 'last_modified_timestamp': '2022-02-11 19:24:41.282 +0000 UTC', 'permissions': ['administrator', 'can_provision', 'manage_catalog', 'create_project', 'create_space', 'author_governance_artifacts', 'manage_governance_workflow', 'view_governance_artifacts', 'manage_categories', 'manage_glossary', 'manage_quality', 'manage_information_assets', 'manage_discovery', 'manage_metadata_import', 'access_catalog', 'view_quality', 'access_information_assets'], 'role': 'Admin', 'uid': '1000330999', 'user_roles': ['zen_administrator_role', 'zen_developer_role', 'wkc_data_scientist_role', 'zen_data_engineer_role', 'wkc_data_steward_role', 'wkc_business_analyst_role', 'wkc_data_quality_analyst_role'], 'username': 'admin'}, {'approval_status': 'approved', 'authenticator': 'defa
# ...

# %%
# Schritt 3 : Modifiziere z.B. Tags oder Data Steward im CSV

# %%
# Schritt 4 : Lese CSV ein
userTable = pandas.read_csv('../csv/userlist_in.csv')        
userTable
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/drangar@us.ibm.com/Documents/GitHub/wkc-api/notebooks/endpoints/users.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/drangar%40us.ibm.com/Documents/GitHub/wkc-api/notebooks/endpoints/users.ipynb#ch0000004?line=0'>1</a> # Schritt 4 : Lese CSV ein
# ----> <a href='vscode-notebook-cell:/Users/drangar%40us.ibm.com/Documents/GitHub/wkc-api/notebooks/endpoints/users.ipynb#ch0000004?line=1'>2</a> userTable = pandas.read_csv('../csv/userlist_in.csv')
#       <a href='vscode-notebook-cell:/Users/drangar%40us.ibm.com/Documents/GitHub/wkc-api/notebooks/endpoints/users.ipynb#ch0000004?line=2'>3</a> userTable
#
# ...

# %%
# Schritt 5 : Update aller Users aus dem CSV
api.updateUsersFromTable(userTable)
# Out:
# 2021-06-22 20:04:14,843 INFO    POST /icp4d-api/v1/users
# 2021-06-22 20:04:14,844 INFO    PAYLOAD: {'user_name': 'test', 'password': 'password', 'displayName': 'Test User', 'user_roles': ['wkc_business_analyst_role', 'wkc_data_quality_analyst_role', 'wkc_data_scientist_role', 'wkc_data_steward_role', 'zen_administrator_role', 'zen_data_engineer_role', 'zen_developer_role', 'zen_user_role'], 'email': 'joerg.rehr@de.ibm.com'}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-02a4870359af> in <module>
#       1 # Schritt 5 : Update aller Users aus dem CSV
# ----> 2 api.updateUsersFromTable(userTable)
#
# ~/dev/wkc-api/notebooks/../apis/users.py in updateUsersFromTable(self, userTable)
#      52   def updateUsersFromTable(self, userTable):
#      53     for _, userRow in userTable.iterrows():
# ---> 54         self._updateUserFromRow(userRow)
#      55
# ...

# %%
api.getRoleByName("Administrator")
# Out:
# 2022-03-10 07:12:58,702 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 07:12:58,703 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....PvunpXION4FYYjkEn1FdR3ipfmvN9YiWU0ROw0I6aZU5ufSDUHCXAhq1MJheUzitctOJN7xA87D_klFw20dRMcuR16EmeP7Wc3eJ4XxcEsIxoP-tZ-kxhmXaDswlFOXMnoOSVIcftsFOF09YnLm6aI2vVn2gnknuZGIpGOnEpPJ0ELH30VrVT64kvs592pcrvA6XO2OfzeH1hPcNvO6Sgabt8zvyUGjQiTEGKbCxfKXe19kak6zqFuvpRzRaCm4rVV7rIPkQ3bZNQruB2JEIbzkVrEw16KMEdTFNLCiKIP3Tk83AbZZv7zV_Zm-AG8GqdZg6KqoL7Ol_Xqe2mkvxwg', 'Content-Type': 'application/json'}
# 2022-03-10 07:12:58,712 INFO    GET /icp4d-api/v1/roles
# 2022-03-10 07:12:58,714 DEBUG   Resetting dropped connection: datafabric.ibmcloudpack.com
# 2022-03-10 07:12:59,098 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /icp4d-api/v1/roles HTTP/1.1" 200 None
# 2022-03-10 07:12:59,099 DEBUG   Res: <Response [200]>
# ...

# %%
api.getUser('admin')
# Out:
# 2022-03-10 07:13:06,769 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 07:13:06,770 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....PvunpXION4FYYjkEn1FdR3ipfmvN9YiWU0ROw0I6aZU5ufSDUHCXAhq1MJheUzitctOJN7xA87D_klFw20dRMcuR16EmeP7Wc3eJ4XxcEsIxoP-tZ-kxhmXaDswlFOXMnoOSVIcftsFOF09YnLm6aI2vVn2gnknuZGIpGOnEpPJ0ELH30VrVT64kvs592pcrvA6XO2OfzeH1hPcNvO6Sgabt8zvyUGjQiTEGKbCxfKXe19kak6zqFuvpRzRaCm4rVV7rIPkQ3bZNQruB2JEIbzkVrEw16KMEdTFNLCiKIP3Tk83AbZZv7zV_Zm-AG8GqdZg6KqoL7Ol_Xqe2mkvxwg', 'Content-Type': 'application/json'}
# 2022-03-10 07:13:06,778 INFO    GET /icp4d-api/v1/users/admin
# 2022-03-10 07:13:06,976 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /icp4d-api/v1/users/admin HTTP/1.1" 200 949
# 2022-03-10 07:13:06,977 DEBUG   Res: <Response [200]>
# ...

# %%
api.getUserIdByName('admin')
# Out:
# 2022-03-10 07:13:14,551 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 07:13:14,551 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....PvunpXION4FYYjkEn1FdR3ipfmvN9YiWU0ROw0I6aZU5ufSDUHCXAhq1MJheUzitctOJN7xA87D_klFw20dRMcuR16EmeP7Wc3eJ4XxcEsIxoP-tZ-kxhmXaDswlFOXMnoOSVIcftsFOF09YnLm6aI2vVn2gnknuZGIpGOnEpPJ0ELH30VrVT64kvs592pcrvA6XO2OfzeH1hPcNvO6Sgabt8zvyUGjQiTEGKbCxfKXe19kak6zqFuvpRzRaCm4rVV7rIPkQ3bZNQruB2JEIbzkVrEw16KMEdTFNLCiKIP3Tk83AbZZv7zV_Zm-AG8GqdZg6KqoL7Ol_Xqe2mkvxwg', 'Content-Type': 'application/json'}
# 2022-03-10 07:13:14,560 INFO    GET /icp4d-api/v1/users/admin
# 2022-03-10 07:13:14,777 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /icp4d-api/v1/users/admin HTTP/1.1" 200 949
# 2022-03-10 07:13:14,778 DEBUG   Res: <Response [200]>
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import logging
logging.basicConfig(format="%(asctime)s %(levelname)-7s %(message)s", level=logging.DEBUG)
import sys
sys.path.append('../..')
import apis
from apis import endpoints
api = endpoints.ConnectionsAPI()
cat_api = endpoints.CatalogsAPI()
# Out:
# 2022-03-11 15:30:26,948 DEBUG   calling SubAPI init
# 2022-03-11 15:30:26,949 DEBUG   None
# 2022-03-11 15:30:26,950 INFO    URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-11 15:30:26,962 DEBUG   Starting new HTTPS connection (1): datafabric.ibmcloudpack.com:12864
# 2022-03-11 15:30:27,645 DEBUG   https://datafabric.ibmcloudpack.com:12864 "POST /icp4d-api/v1/authorize HTTP/1.1" 200 1261
# 2022-03-11 15:30:27,647 INFO    HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....ShpL6U3NBwncHib8qCzMfFAQmQZRFO0_UA2qRD2g9cIapnf9lYlyeg3TsdbwwQ0IWK4EKk1eqiDF0e9CimrsiY4eocXy_euGAnGNisROFDjhCH3C0De6jGAcSKKDaLkcYUPv-242b0j6_3J0Fe_2BlyBq5FgaC89Sau5HYgJLlxolYrZ5O4qhzn-QbPbQNDVeQj-vusWEoHrbGpMT1Ybgf8-E7ceyNsGJhp9MmVq_pwYxoWLUAxeinhdVLDv4A7ZA0BJ5jOhHk8-6Ky03jhWk1Oue6N6df_D71vhCgkWCUKjqcIwXDUeY0CVE4pZqaEPEUa9O5tAVxwRyyy52aO8dA'}
# ...

# %%
catalogId = cat_api.getCatalogIdByName("Churn Data Catalog")
catalogId
# Out:
# 2022-03-11 15:30:32,630 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-11 15:30:32,630 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....cM1muSMiThUDoQVdWSGK7cY-ZH1ve4-liev0Zb8Ei_2fgC2zzndLrjW3WpOgoE2QvXLwjTDoxd-QU5TCXVQn4_jHi6ivQUVRbri4XoIXRqUxsRcisgvQZcnTXs3txgEB1aDgjw7c5NQp21HtNE0Jog2W0FiWwJ_tw-jn4KVj4clR8UeXltSPk8Q5R9sW-O8NcQc7b7b741m_OisE86tZiL7Ed3qYiVnU21QAg4K5jIbXD2TkZnm8kgQtTebLgkZBYGgtBDrMMbBWVMTMMBII--D5Z5sUp4m4RpZCk9nthG6x5hE2I7K7qdMo2ZENrXlPQjIQFpRlyhmYMUhfNLuUEw', 'Content-Type': 'application/json'}
# 2022-03-11 15:30:32,837 INFO    GET /v2/catalogs
# 2022-03-11 15:30:32,956 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /v2/catalogs HTTP/1.1" 200 1962
# 2022-03-11 15:30:32,957 DEBUG   Res: <Response [200]>
# ...

# %%
api.getListOfConnections(catalogId)["total_count"]
# Out:
# 2022-03-11 15:30:36,624 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-11 15:30:36,625 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....ShpL6U3NBwncHib8qCzMfFAQmQZRFO0_UA2qRD2g9cIapnf9lYlyeg3TsdbwwQ0IWK4EKk1eqiDF0e9CimrsiY4eocXy_euGAnGNisROFDjhCH3C0De6jGAcSKKDaLkcYUPv-242b0j6_3J0Fe_2BlyBq5FgaC89Sau5HYgJLlxolYrZ5O4qhzn-QbPbQNDVeQj-vusWEoHrbGpMT1Ybgf8-E7ceyNsGJhp9MmVq_pwYxoWLUAxeinhdVLDv4A7ZA0BJ5jOhHk8-6Ky03jhWk1Oue6N6df_D71vhCgkWCUKjqcIwXDUeY0CVE4pZqaEPEUa9O5tAVxwRyyy52aO8dA', 'Content-Type': 'application/json'}
# 2022-03-11 15:30:36,634 INFO    GET /v2/connections?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# 2022-03-11 15:30:37,482 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /v2/connections?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49 HTTP/1.1" 200 8951
# 2022-03-11 15:30:37,483 DEBUG   Res: <Response [200]>
# ...

# %%
#api.getListOfSSLConnections(catalogID,"DAK DB2 SSL")["total_count"]
api.getListOfSSLConnections(catalogId,"DAK DB2 SSL")
# Out:
# 2022-03-11 15:30:43,191 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-11 15:30:43,191 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....ShpL6U3NBwncHib8qCzMfFAQmQZRFO0_UA2qRD2g9cIapnf9lYlyeg3TsdbwwQ0IWK4EKk1eqiDF0e9CimrsiY4eocXy_euGAnGNisROFDjhCH3C0De6jGAcSKKDaLkcYUPv-242b0j6_3J0Fe_2BlyBq5FgaC89Sau5HYgJLlxolYrZ5O4qhzn-QbPbQNDVeQj-vusWEoHrbGpMT1Ybgf8-E7ceyNsGJhp9MmVq_pwYxoWLUAxeinhdVLDv4A7ZA0BJ5jOhHk8-6Ky03jhWk1Oue6N6df_D71vhCgkWCUKjqcIwXDUeY0CVE4pZqaEPEUa9O5tAVxwRyyy52aO8dA', 'Content-Type': 'application/json'}
# 2022-03-11 15:30:43,199 INFO    GET /v2/connections?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49&entity.properties.ssl=true&entity.name=DAK DB2 SSL
# ...

# %%
api.getConnection("fa4f6386-eb9d-4cb2-bde0-f3a1ba993a30",catalogId)
# Out:
# 2022-03-11 15:27:37,942 INFO    GET /v2/connections/fa4f6386-eb9d-4cb2-bde0-f3a1ba993a30?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# {'metadata': {'asset_id': 'fa4f6386-eb9d-4cb2-bde0-f3a1ba993a30',
#   'asset_type': 'connection',
#   'asset_category': 'USER',
#   'catalog_id': '295d4b84-5131-4310-9d5b-9c18b6eb8a49',
#   'create_time': '2022-02-08T00:11:35.000Z',
#   'creator_id': '1000331005',
#   'tags': [],
#   'usage': {'last_access_time': '2022-02-08T00:11:35.741Z',
#    'last_accessor_id': 'icp4d-dev',
#    'access_count': 0}},
#  'entity': {'datasource_type': 'cfdcb449-1204-44ba-baa6-9a8a878e6aa7',
#   'description': '',
#   'name': 'Db2 Customer Personal Information',
#   'ref_catalog_id': 'cab51b37-6be4-41f5-b331-81e598f2ce82',
#   'ref_asset_id': '89971dd3-9f77-4f10-9195-10f6635784af',
#   'origin_country': 'us',
#   'owner_id': '1000331005',
#   'rov': {'mode': 0},
#   'properties': {'database': 'BLUDB',
#    'password': 'passw0rd',
#    'port': '50000',
# ...

# %%
api.getConnectionAssets("fa4f6386-eb9d-4cb2-bde0-f3a1ba993a30",catalogId)
# Out:
# 2022-03-11 15:30:50,151 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-11 15:30:50,152 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....ShpL6U3NBwncHib8qCzMfFAQmQZRFO0_UA2qRD2g9cIapnf9lYlyeg3TsdbwwQ0IWK4EKk1eqiDF0e9CimrsiY4eocXy_euGAnGNisROFDjhCH3C0De6jGAcSKKDaLkcYUPv-242b0j6_3J0Fe_2BlyBq5FgaC89Sau5HYgJLlxolYrZ5O4qhzn-QbPbQNDVeQj-vusWEoHrbGpMT1Ybgf8-E7ceyNsGJhp9MmVq_pwYxoWLUAxeinhdVLDv4A7ZA0BJ5jOhHk8-6Ky03jhWk1Oue6N6df_D71vhCgkWCUKjqcIwXDUeY0CVE4pZqaEPEUa9O5tAVxwRyyy52aO8dA', 'Content-Type': 'application/json'}
# 2022-03-11 15:30:50,161 INFO    GET /v2/connections/fa4f6386-eb9d-4cb2-bde0-f3a1ba993a30/assets?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import logging
logging.basicConfig(format="%(asctime)s %(levelname)-7s %(message)s", level=logging.DEBUG)
import sys
sys.path.append('../..')
from apis import endpoints
a_api = endpoints.AssetsAPI()
c_api = endpoints.CatalogsAPI(a_api.mainAPI)
# Out:
# 2022-03-14 23:27:52,368 DEBUG   calling SubAPI init
# 2022-03-14 23:27:52,371 DEBUG   None
# 2022-03-14 23:27:52,372 INFO    URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-14 23:27:52,380 DEBUG   Starting new HTTPS connection (1): datafabric.ibmcloudpack.com:12864
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-14 23:27:52,808 DEBUG   https://datafabric.ibmcloudpack.com:12864 "POST /icp4d-api/v1/authorize HTTP/1.1" 200 1261
# ...

# %%
a_api.getAssetTypeRelationships('data_asset')
# Out:
# 2022-03-10 13:52:02,679 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 13:52:02,680 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 13:52:02,900 INFO    GET /v2/asset_types/data_asset/relationships
# 2022-03-10 13:52:03,175 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /v2/asset_types/data_asset/relationships HTTP/1.1" 200 2169
# 2022-03-10 13:52:03,176 DEBUG   Res: <Response [200]>
# ...

# %%
catalogId = c_api.getCatalogIdByName('Churn Data Catalog')
#catalogId = c_api.getDefaultCatalogId()
catalogId
# Out:
# 2022-03-14 23:28:15,161 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-14 23:28:15,162 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....c7LkqreqvJe6SPtjDxae_p0Oe2s0imSAk55HmB-jise5_Mt-NgqDtoV33YhVxxWof4gPFm72eeC0jeqP2gqz3skTh9bGYQeWbxL541g3bkEbZ7ldiVeEqvxeGnCTDwgKkrIjHPZboCses_9r4vWfYLH2IJApiX2LUQlSvMBXKOR4KrRUstd_GoAnaEoUI9Blh8ODpNrlmLITOKYCakW5e9v91DF9RzcC3yNVqoKr872qRaRlwTTjiKA2FTX_U5rkQo9mGcIoTgwoK2QUi0WldLw1yuiAacSo_zewna1EvSWxHr2fGBSDbSs5sRo1ewnzgygNvPREwBoAwZPQdU7gcA', 'Content-Type': 'application/json'}
# 2022-03-14 23:28:15,180 INFO    GET /v2/catalogs
# 2022-03-14 23:28:15,304 DEBUG   https://datafabric.ibmcloudpack.com:12864 "GET /v2/catalogs HTTP/1.1" 200 1962
# 2022-03-14 23:28:15,305 DEBUG   Res: <Response [200]>
# ...

# %%
a_api.getListOfAllDataAssets(catalogId)
# Out:
# 2022-03-10 14:07:08,538 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 14:07:08,539 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 14:07:08,548 INFO    POST /v2/asset_types/data_asset/search?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# 2022-03-10 14:07:08,548 INFO    PAYLOAD: {'query': '*:*'}
# 2022-03-10 14:07:08,549 DEBUG   adding json
# 2022-03-10 14:07:08,551 DEBUG   Resetting dropped connection: datafabric.ibmcloudpack.com
# ...

# %%
assetId = a_api.getAssetIds(catalogId, '\/CUSTOMER\/CUSTOMER_PERSONAL_INFO')
assetId
# Out:
# 2022-03-10 14:18:28,874 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 14:18:28,875 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 14:18:28,882 INFO    GET /v3/search?query=entity.assets.connection_paths.keyword:\/CUSTOMER\/CUSTOMER_PERSONAL_INFO AND metadata.artifact_type:data_asset AND entity.assets.catalog_id:295d4b84-5131-4310-9d5b-9c18b6eb8a49
# 2022-03-10 14:18:28,885 DEBUG   Resetting dropped connection: datafabric.ibmcloudpack.com
# ...

# %%
assetId = '83ff263b-3afc-44c6-9656-239dd46b7423'
res = a_api.getAssetById(assetId, catalogId)
res
# Out:
# 2022-03-10 14:19:06,194 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 14:19:06,195 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 14:19:06,204 INFO    GET /v2/assets/83ff263b-3afc-44c6-9656-239dd46b7423?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# ...

# %%
assetId = '83ff263b-3afc-44c6-9656-239dd46b7423'
res = a_api.getAssetById(assetId, catalogId)
res
# Out:
# 2022-03-10 14:19:34,346 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 14:19:34,347 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 14:19:34,355 INFO    GET /v2/assets/83ff263b-3afc-44c6-9656-239dd46b7423?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# ...

# %%
assetId = '93e3c8f1-78d9-4026-9507-ae017d6f2d4b'
res = a_api.getAssetById(assetId, catalogId)
res
# Out:
# 2022-02-12 20:45:58,661 INFO    GET /v2/assets/93e3c8f1-78d9-4026-9507-ae017d6f2d4b?catalog_id=7ce6b0cc-ca2d-4f50-8fdb-1b56377ba886
# {'metadata': {'usage': {'last_updated_at': '2022-02-12T08:10:55Z',
#    'last_updater_id': '1000330999',
#    'last_update_time': 1644653455062,
#    'last_accessed_at': '2022-02-12T08:10:55Z',
#    'last_access_time': 1644653455062,
#    'last_accessor_id': '1000330999',
#    'access_count': 0},
#   'rov': {'mode': 0,
#    'collaborator_ids': {},
#    'member_roles': {'1000330999': {'user_iam_id': '1000330999',
#      'roles': ['OWNER']}}},
#   'name': 'tk.png',
#   'description': '',
#   'tags': [],
#   'asset_type': 'data_asset',
#   'origin_country': 'none',
#   'resource_key': 'tk.png',
#   'rating': 0.0,
#   'total_ratings': 0,
#   'catalog_id': '7ce6b0cc-ca2d-4f50-8fdb-1b56377ba886',
#   'created': 1644653454731,
#   'created_at': '2022-02-12T08:10:54Z',
#   'owner_id': '1000330999',
#   'size': 0,
#   'version': 2.0,
# ...

# %%
idx = res["metadata"]["tags"].index('customer')
idx
# Out:
# {'metadata': {'usage': {'last_updated_at': '2022-02-08T00:11:38Z',
#    'last_updater_id': '1000331005',
#    'last_update_time': 1644279098288,
#    'last_accessed_at': '2022-02-08T00:11:38Z',
#    'last_access_time': 1644279098288,
#    'last_accessor_id': '1000331005',
#    'access_count': 0},
#   'rov': {'mode': 0,
#    'collaborator_ids': {},
#    'member_roles': {'1000331005': {'user_iam_id': '1000331005',
#      'roles': ['OWNER']}}},
#   'name': 'CUSTOMER_PERSONAL_INFO',
#   'description': '',
#   'tags': [],
#   'asset_type': 'data_asset',
#   'origin_country': 'us',
#   'resource_key': 'NGQS_c-db2wh-1641924859188375-db2u-engn-svc:50000/BLUDB/CUSTOMER.CUSTOMER_PERSONAL_INFO',
#   'rating': 0.0,
#   'total_ratings': 0,
#   'catalog_id': '295d4b84-5131-4310-9d5b-9c18b6eb8a49',
#   'created': 1644279097593,
#   'created_at': '2022-02-08T00:11:37Z',
#   'owner_id': '1000331005',
#   'size': 229178,
#   'version': 2.0,
#   'asset_state': 'available',
# ...

# %%
a_api.addTagToAsset(catalogId, assetId, 'Demo')
# Out:
# 2022-03-10 14:22:03,726 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 14:22:03,727 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 14:22:03,736 INFO    PATCH /v2/assets/83ff263b-3afc-44c6-9656-239dd46b7423?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# 2022-03-10 14:22:03,737 INFO    PAYLOAD: [{'op': 'add', 'path': '/metadata/tags/-', 'value': 'Demo'}]
# 2022-03-10 14:22:03,738 DEBUG   adding json
# ...

# %%
idx="tag1"
a_api.removeTagFromAsset(catalogId, assetId, idx)
# Out:
# 2022-03-10 14:23:07,490 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 14:23:07,490 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 14:23:07,499 INFO    PATCH /v2/assets/83ff263b-3afc-44c6-9656-239dd46b7423?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# 2022-03-10 14:23:07,499 INFO    PAYLOAD: [{'op': 'remove', 'path': '/metadata/tags/tag1'}]
# 2022-03-10 14:23:07,500 DEBUG   adding json
# ...

# %%
res = a_api.getAssetAttributes(assetId,catalogId)
res
# Out:
# 2021-10-07 21:14:00,183 INFO    GET /v2/assets/c48b0b61-0a74-40cf-9369-dbbd6c8a5aa3/attributes?catalog_id=3e2a28ef-64b4-448e-951e-18340dc65b05
# {'resources': [{'href': '/v2/assets/c48b0b61-0a74-40cf-9369-dbbd6c8a5aa3/attributes/data_asset?catalog_id=3e2a28ef-64b4-448e-951e-18340dc65b05',
#    'asset_id': 'c48b0b61-0a74-40cf-9369-dbbd6c8a5aa3',
#    'data_asset': {'mime_type': 'application/octet-stream',
#     'dataset': True,
#     'properties': [{'name': 'bucket', 'value': 'tkcos'},
#      {'name': 'row_delimiter', 'value': 'new_line'},
#      {'name': 'file_name', 'value': 'tk.png'},
#      {'name': 'first_line_header', 'value': 'true'},
#      {'name': 'encoding', 'value': 'UTF-8'},
#      {'name': 'invalid_data_handling', 'value': 'fail'},
#      {'name': 'field_delimiter', 'value': 'comma'},
#      {'name': 'file_format', 'value': 'delimited'}],
#     'columns': [{'name': '�PNG',
#       'type': {'type': 'varchar',
#        'length': 1024.0,
#        'scale': 0.0,
# ...

# %%
#a_api.updateAsset(assetId,catalogId,payloadFile='assets/addtermtoasset.json')
#a_api.updateAsset(assetId,catalogId,payloadFile='assets/patchAssetTags.json')
#payload = [{ "op": "add", "path": "/metadata/tags/-", "value": "tag1" }]
a_api.patchAssetAttribute(assetId,catalogId,'asset_terms',payloadFile='assets/addtermtoasset.json')
# Out:
# 2021-10-07 21:50:15,179 INFO    Loading Payload: ../../payloads\assets/addtermtoasset.json
# 2021-10-07 21:50:15,219 INFO    PATCH /v2/assets/c48b0b61-0a74-40cf-9369-dbbd6c8a5aa3/attributes/asset_terms?catalog_id=3e2a28ef-64b4-448e-951e-18340dc65b05
# 2021-10-07 21:50:15,221 INFO    PAYLOAD: [{'op': 'replace', 'path': '/list', 'value': [{'term_display_name': 'Versicherte Person', 'term_id': '5d2d5419-0032-4c64-90e2-ce68c6997bb5_e1d44823-b7aa-4a65-bfa3-d32e9180078a'}], 'attribute': 'asset_terms'}]
# 2021-10-07 21:50:16,041 INFO    {"list":[{"term_display_name":"Versicherte Person","term_id":"5d2d5419-0032-4c64-90e2-ce68c6997bb5_e1d44823-b7aa-4a65-bfa3-d32e9180078a"}]}

# %%
a_api.getAssetTypes(catalogId)
# Out:
# 2022-03-10 17:10:34,155 DEBUG   URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-10 17:10:34,156 DEBUG   HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....grMWeFpsG016PJec9UCq2_XZ2OQKaSjB9OJwgMy3E0_EtnIrDCpZhHDr0F1QSQO_mBDrzxZA9-jGTz2Y7g8A-ZCGsxX_9dr9IW8ekPA4OkdlPnjWF0hbZJh9wx9BGnv48Vn6EE708hGgZH0AiWEoUu-_pJg0MiaVr_YWmMPVOXjOgSdU4uVAmNmnpiTam8FeIuopEdJIO_KtLpNXEjBwX7HFF4d-cGESHJDZJvptbloCq82IVEVh_UTdkWADGak02MmeQ8hug3zWNyp1SwNDJuEj3pZw2OrutCybLW56wQirtWeA_YvZuViV4UqmpbgxsHwGN9qCyzQV-PPtZhNDrA', 'Content-Type': 'application/json'}
# 2022-03-10 17:10:34,164 INFO    GET /v2/asset_types?catalog_id=295d4b84-5131-4310-9d5b-9c18b6eb8a49
# 2022-03-10 17:10:34,173 DEBUG   Resetting dropped connection: datafabric.ibmcloudpack.com
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import logging
logging.basicConfig(format="%(asctime)s %(levelname)-7s %(message)s", level=logging.INFO)
import sys
sys.path.append('../..')
import apis
api = apis.MainAPI()
# Out:
# 2022-03-14 15:02:32,922 INFO    URL: https://datafabric.ibmcloudpack.com:12864
# 2022-03-14 15:02:33,405 INFO    HEADERS: {'cache-control': 'no-cache', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjR2TzJpeGJ1UExCZ2dtZEhpNXpSOVFOQ1gzUldNcFY4Q1hqUGZFaHdyNDAifQ.....lZPpQlHhLfTBA8u_jVy1F1IqUX0dPOOvVNUkk_trYdJJ13tlG9CbVvwGhg98oEQSfTI5XMDyAgfAbq7gLXjEEoIaqTX-qX-VMqCPHf258xBB5B3_XNdLNuWtKs5vlzOMs8hVZY6_XSBNjnFBog8tzFtliYSOC80Gxi9sl09sguxjw_iDvZ6rDGtxp7Bden_0ZoWy6h_6xbxLqX1r6Ax5A8G94uGVLejHdnYEiNtTV8eNkCN8KgzuZE_n6SDxGqFTteZ4RiUAiGSWzttu5Bv0qTWT1iubSlYw9Lk9wRw0IKqcBv5Zaaw1ykD4ZMRV6aJjyv7yz6nj5a5bdVwtEg5V9Q'}

# %%
print(api.search.__doc__)
# Out:
# Searches WKC
#     Can be based on lucene parser syntax usable for many search needs
#     Can also take a complex JSON payload usable for very specific search needs
#     Args:
#         searchString (str): Search Phrase. Lucene Parser Syntax can be applied for filtering (https://lucene.apache.org/core/2_9_4/queryparsersyntax.html)
#     Returns:
#         dict: Search result with `dict_keys(['size', 'rows', 'aggregations'])`

# %%
api.search("Customer")
# Out:
# 2022-03-14 15:03:04,573 INFO    GET /v3/search?query=Customer
# {'size': 12,
#  'rows': [{'provider_type_id': 'glossary',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2022-01-07T01:09:25.651Z',
#     'artifact_type': 'data_class',
#     'name': 'Customer Number',
#     'modified_by': '1000330999',
#     'description': 'A value representing a customer Number.',
#     'state': 'PUBLISHED',
#     'steward_ids': [],
#     'tags': []},
#    'last_updated_at': 1644608539481,
#    'categories': {'secondary_category_ids': [],
#     'last_updated_at': 1644608539479,
#     'secondary_category_global_ids': [],
#     'primary_category_global_id': '4e07dd80-9270-43f4-a804-f7c7b967870f_e39ada11-8338-3704-90e3-681a71e7c839',
#     'primary_category_id': 'e39ada11-8338-3704-90e3-681a71e7c839',
#     'primary_category_name': '[uncategorized]',
#     'secondary_category_names': []},
#    'artifact_id': '7ab9eaa3-ee71-4444-81b5-0a1991ed1215',
# ...

# %%
api.search('Person')
# Out:
# 2021-04-30 12:06:07,928 INFO    --- GET (search) ---
# 2021-04-30 12:06:07,932 INFO    ENDPOINT: /v3/search?query=Person
# 2021-04-30 12:06:07,934 INFO    PAYLOAD: None
# ider_type_id': 'glossary',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2020-12-05T18:53:47.719Z',
#     'classifications': [],
#     'artifact_type': 'data_class',
#     'term_global_ids': [],
#     'classification_global_ids': [],
#     'terms': [],
#     'name': 'Honorific',
#     'modified_by': 'System',
#     'description': 'Salutation of a person added before the first name (name prefix).',
#     'state': 'PUBLISHED',
#     'steward_ids': [],
#     'tags': []},
#    'last_updated_at': 1619427782298,
#    'categories': {'secondary_category_ids': [],
#     'last_updated_at': 1619427782290,
#     'secondary_category_global_ids': [],
#     'primary_category_global_id': '5d2d5419-0032-4c64-90e2-ce68c6997bb5_e39ada11-8338-3704-90e3-681a71e7c839',
# ...

# %%
# def getGlossaryTermIds(asset_name, category_name):
api.search('metadata.name.keyword:Adresse AND categories.primary_category_name.keyword:Versicherte AND metadata.artifact_type:glossary_term')
# Out:
# 2021-05-22 21:18:30,239 INFO    GET /v3/search?query=metadata.name.keyword:Adresse AND categories.primary_category_name.keyword:Versicherte AND metadata.artifact_type:glossary_term
# {'size': 1,
#  'rows': [{'provider_type_id': 'glossary',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-05-21T19:21:21.806Z',
#     'classifications': [],
#     'artifact_type': 'glossary_term',
#     'classification_global_ids': [],
#     'name': 'Adresse',
#     'modified_by': '1000330999',
#     'description': 'Adresse unter der eine Person erreicht werden kann\n\nReihenfolge (falls ID = 5 Null ist):\n1. Meldeadresse (Typ 5), 2. Zustelladresse (Typ 6), 3. Firmenanschrift (Typ 3),\n4. Bevollmächtigtenadresse (Typ 1),\n5. Zweitwohnsitz (Typ 7), 6. Mahnadresse (Typ 4), 7. Ferienadresse (Typ 2)',
#     'state': 'PUBLISHED',
#     'steward_ids': [],
#     'tags': []},
#    'last_updated_at': 1621624882065,
#    'categories': {'secondary_category_ids': [],
# ...

# %%
# def getAssetId(catalog, assetPath):
api.search('entity.assets.connection_paths.keyword:/HDS/PP_NATUERLICHEPERSON_DATA AND metadata.artifact_type:data_asset AND entity.assets.catalog_id:98f756fc-8092-45cd-9b3a-e22dfc8d11f2')
# Out:
# 2021-04-20 21:00:20,326 INFO    Search for: entity.assets.connection_paths.keyword:/HDS/PP_NATUERLICHEPERSON_DATA AND metadata.artifact_type:data_asset AND entity.assets.catalog_id:98f756fc-8092-45cd-9b3a-e22dfc8d11f2
# {'size': 3,
#  'rows': [{'provider_type_id': 'cams',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-04-08T15:23:28Z',
#     'classifications': [],
#     'artifact_type': 'data_asset',
#     'classification_global_ids': [],
#     'name': 'PP_NATUERLICHEPERSON_DATA',
#     'modified_by': 'icp4d-dev',
#     'steward_ids': ['icp4d-dev'],
#     'state': 'active'},
#    'last_updated_at': 1617895408409,
#    'artifact_id': '4ab8ea37-ca1e-47a0-805e-ba3390b21ce0',
#    'entity': {'assets': {'catalog_id': '98f756fc-8092-45cd-9b3a-e22dfc8d11f2',
#      'connection_paths': [],
#      'column_terms': [],
#      'column_data_class_names': [],
#      'column_terms_global_ids': [],
#      'column_names': ['OID',
#       'CREATEDBY',
#       'CREATEDAT',
# ...

# %%
# def getListOfAssets():
api.search('metadata.artifact_type:data_asset AND entity.assets.catalog_id:98f756fc-8092-45cd-9b3a-e22dfc8d11f2')["size"]
# Out:
# 2021-04-20 21:02:44,413 INFO    Search for: metadata.artifact_type:data_asset AND entity.assets.catalog_id:98f756fc-8092-45cd-9b3a-e22dfc8d11f2
# 32

# %%
# def getListOfCategories():
api.search('metadata.artifact_type:category')
# Out:
# 2021-04-20 21:03:35,934 INFO    Search for: metadata.artifact_type:category
# {'size': 18,
#  'rows': [{'provider_type_id': 'glossary',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-04-08T07:43:52.448Z',
#     'artifact_type': 'category',
#     'name': 'Versicherte',
#     'modified_by': '1000330999',
#     'description': '',
#     'state': 'PUBLISHED',
#     'steward_ids': [],
#     'tags': []},
#    'last_updated_at': 1618475866216,
#    'categories': {'last_updated_at': 1618475866207,
#     'primary_category_global_id': '5d2d5419-0032-4c64-90e2-ce68c6997bb5_c1df3618-d77a-4146-874c-d6711bf711bd',
#     'primary_category_id': 'c1df3618-d77a-4146-874c-d6711bf711bd',
#     'primary_category_name': 'Mitgliederverwaltung'},
#    'artifact_id': '285e46e3-70fc-4a11-b3d9-eb356df1fb42',
#    'entity': {'artifacts': {'global_id': '5d2d5419-0032-4c64-90e2-ce68c6997bb5_285e46e3-70fc-4a11-b3d9-eb356df1fb42',
#      'version_id': 'efc631f0-78e7-41cb-bc20-85a2772b80cf_1',
# ...

# %%
# def getTopLevelCategories():
api.search('metadata.artifact_type:category NOT categories.primary_category_name:*')
# Out:
# 2021-04-20 21:06:42,330 INFO    Search for: metadata.artifact_type:category NOT categories.primary_category_name:*
# {'size': 3,
#  'rows': [{'provider_type_id': 'glossary',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-04-08T07:43:33.279Z',
#     'artifact_type': 'category',
#     'name': 'Mitgliederverwaltung',
#     'modified_by': '1000330999',
#     'description': '',
#     'state': 'PUBLISHED',
#     'steward_ids': [],
#     'tags': []},
#    'last_updated_at': 1617902106015,
#    'categories': {'last_updated_at': 1617902105917},
#    'artifact_id': 'c1df3618-d77a-4146-874c-d6711bf711bd',
#    'entity': {'artifacts': {'global_id': '5d2d5419-0032-4c64-90e2-ce68c6997bb5_c1df3618-d77a-4146-874c-d6711bf711bd',
#      'version_id': '3a2c9c85-a991-4337-9b87-997aba6cfbec_1',
#      'artifact_id': 'c1df3618-d77a-4146-874c-d6711bf711bd'}},
#    'custom_attributes': [],
#    '_score': 2.4849067},
#   {'provider_type_id': 'glossary',
#    'tenant_id': '999',
# ...

# %%
# def getListOfRefData(refDataName):
api.search('metadata.name.keyword:Geschlecht AND metadata.artifact_type:reference_data')
# Out:
# 2021-04-20 21:07:54,702 INFO    Search for: metadata.name.keyword:Geschlecht AND metadata.artifact_type:reference_data
# {'size': 1,
#  'rows': [{'provider_type_id': 'glossary',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-04-08T13:59:42.506Z',
#     'artifact_type': 'reference_data',
#     'name': 'Geschlecht',
#     'modified_by': '1000330999',
#     'description': 'Wertebereich für Geschlecht',
#     'state': 'PUBLISHED',
#     'steward_ids': [],
#     'tags': []},
#    'last_updated_at': 1617902106315,
#    'categories': {'secondary_category_ids': [],
#     'last_updated_at': 1617902106295,
#     'secondary_category_global_ids': [],
#     'primary_category_global_id': '5d2d5419-0032-4c64-90e2-ce68c6997bb5_285e46e3-70fc-4a11-b3d9-eb356df1fb42',
#     'primary_category_id': '285e46e3-70fc-4a11-b3d9-eb356df1fb42',
#     'primary_category_name': 'Versicherte',
#     'secondary_category_names': []},
#    'artifact_id': 'ae7d3658-7552-455b-89aa-54cb8777b550',
# ...

# %%
# return only connections
api.getCatalogIdByName("DAK PoC")
api.search('metadata.artifact_type:connection AND entity.assets.catalog_id:98f756fc-8092-45cd-9b3a-e22dfc8d11f2')
# Out:
# 2021-04-21 16:30:32,716 INFO    Catalog ID is: 98f756fc-8092-45cd-9b3a-e22dfc8d11f2
# 2021-04-21 16:30:32,716 INFO    Search for: metadata.artifact_type:connection AND entity.assets.catalog_id:98f756fc-8092-45cd-9b3a-e22dfc8d11f2
# {'size': 5,
#  'rows': [{'provider_type_id': 'cams',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-04-06T21:12:15Z',
#     'artifact_type': 'connection',
#     'name': 'Db2 DAK',
#     'modified_by': '1000330999',
#     'steward_ids': ['1000330999'],
#     'state': 'active'},
#    'last_updated_at': 1617743535976,
#    'artifact_id': '09102f26-6b8f-45dd-a7c9-da84a2e8f92a',
#    'entity': {'assets': {'catalog_id': '98f756fc-8092-45cd-9b3a-e22dfc8d11f2'}},
#    '_score': 3.3322046},
#   {'provider_type_id': 'cams',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-04-10T09:39:43Z',
#     'artifact_type': 'connection',
#     'name': 'Data Virtualization',
#     'modified_by': 'icp4d-dev',
#     'steward_ids': ['icp4d-dev'],
# ...

# %%
#api.search('metadata.asset_type:rest_api') #geht
#api.search('metadata.artifact_type:rest_api AND metadata.tags:wkc') #geht
api.search('metadata.name:API')
#api.search('custom_attributes.attribute_name:Type and custom_attributes.attribute_value:GET') # geht nicht gegen 3.5
#api.search('rest_api') #geht
#api.search('entity.product.short_name:WKC') #geht nicht gegen 3.5
# Out:
# 2021-12-08 19:43:06,430 INFO    GET /v3/search?query=metadata.name:API
# {'size': 5,
#  'rows': [{'provider_type_id': 'cams',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-10-27T18:41:25Z',
#     'artifact_type': 'rest_api',
#     'name': 'Rest API 1',
#     'modified_by': '1000330999',
#     'description': 'Represents Rest API 1',
#     'steward_ids': ['1000330999'],
#     'state': 'active',
#     'tags': ['wkc'],
#     'classifications': [],
#     'classification_global_ids': []},
#    'last_updated_at': 1635360085795,
#    'artifact_id': '5c0d3f97-6536-4177-9a71-d7ed2e6e59a9',
#    'entity': {'assets': {'catalog_id': 'c38e1000-59a1-44d2-81ab-19640e877389',
#      'connection_paths': [],
#      'column_names': [],
#      'connection_ids': []}},
#    '_score': 5.8197947},
#   {'provider_type_id': 'cams',
#    'tenant_id': '999',
#    'metadata': {'modified_on': '2021-10-27T18:42:46Z',
#     'artifact_type': 'rest_api',
#     'name': 'Rest API 1',
# ...
